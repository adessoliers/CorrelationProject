# %% [markdown]
# ## Import Dependencies

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

import seaborn as sns
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read in CSV

# %%
cleaned_df = pd.read_csv('data/movies_df_clean.csv')
cleaned_df
# Out:
#                                                 Name     Rating      Genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
#       Score    Votes         Director                   Writer  \
# 0       8.4   927000  Stanley Kubrick             Stephen King
# 1       5.8    65000   Randal Kleiser  Henry De Vere Stacpoole
# 2       8.7  1200000   Irvin Kershner           Leigh Brackett
# 3       7.7   221000     Jim Abrahams             Jim Abrahams
# 4       7.3   108000     Harold Ramis       Brian Doyle-Murray
# ...     ...      ...              ...                      ...
# 5416    6.6   140000     Adil El Arbi              Peter Craig
# 5417    6.5   102000      Jeff Fowler                Pat Casey
# 5418    5.6    53000   Stephen Gaghan           Stephen Gaghan
# 5419    6.8    42000    Chris Sanders            Michael Green
# 5420    6.8     3700          Hu Guan                  Hu Guan
#
#                    Star     Budget      Gross  \
# 0        Jack Nicholson   19000000   46998772
# 1        Brooke Shields    4500000   58853106
# 2           Mark Hamill   18000000  538375067
# 3           Robert Hays    3500000   83453539
# 4           Chevy Chase    6000000   39846344
# ...                 ...        ...        ...
# 5416         Will Smith   90000000  426505244
# 5417       Ben Schwartz   85000000  319715683
# 5418  Robert Downey Jr.  175000000  245487753
# 5419      Harrison Ford  135000000  111105497
# 5420    Zhi-zhong Huang   80000000  461421559
#
#                                   Company  Runtime  Year released  \
# 0                            Warner Bros.      146           1980
# 1                       Columbia Pictures      104           1980
# 2                               Lucasfilm      124           1980
# 3                      Paramount Pictures       88           1980
# 4                          Orion Pictures       98           1980
# ...                                   ...      ...            ...
# 5416                    Columbia Pictures      124           2020
# 5417                   Paramount Pictures       99           2020
# 5418                   Universal Pictures      101           2020
# 5419                 20th Century Studios      100           2020
# 5420  Beijing Diqi Yinxiang Entertainment      149           2020
#
#      Country released
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
# ...               ...
# 5416    United States
# 5417    United States
# 5418    United States
# 5419    United States
# 5420    United States
#
# [5421 rows x 14 columns]

# %% [markdown]
# ## Data Exploration!

# %%
# Sorting values to see the top 5 by 'gross'

cleaned_df.sort_values(by=['Gross'], inplace=False, ascending=False).head(5)
# Out:
#                                             Name Rating   Genre  Score  \
# 3731                                      Avatar  PG-13  Action    7.8
# 5302                           Avengers: Endgame  PG-13  Action    8.4
# 1795                                     Titanic  PG-13   Drama    7.8
# 4730  Star Wars: Episode VII - The Force Awakens  PG-13  Action    7.8
# 5158                      Avengers: Infinity War  PG-13  Action    8.4
#
#         Votes       Director              Writer               Star  \
# 3731  1100000  James Cameron       James Cameron    Sam Worthington
# 5302   903000  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 1795  1100000  James Cameron       James Cameron  Leonardo DiCaprio
# 4730   876000    J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 5158   897000  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#          Budget       Gross                Company  Runtime  Year released  \
# 3731  237000000  2847246203  Twentieth Century Fox      162           2009
# 5302  356000000  2797501328         Marvel Studios      181           2019
# 1795  200000000  2201647264  Twentieth Century Fox      194           1997
# 4730  245000000  2069521700              Lucasfilm      138           2015
# 5158  321000000  2048359754         Marvel Studios      149           2018
#
#      Country released
# 3731    United States
# 5302    United States
# 1795    United States
# 4730    United States
# 5158    United States

# %%
# Scatter plot budget vs gross

plt.scatter(x=cleaned_df['Budget'], y=cleaned_df['Gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Film')

plt.show()

# %%
# Plot 

sns.regplot(x='Budget', y='Gross', data=cleaned_df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='Budget', ylabel='Gross'>
